# %%
import json
import pandas as pd
import requests
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.DataFrame(json.loads(requests.get("http://ntsfranz.crabdance.com/how_many_monke_graph?hours=336").text))
# df = pd.DataFrame(json.loads(requests.get("http://localhost:5000/how_many_monke_graph").text))
df['timestamp'] = pd.to_datetime(df['timestamp'])
df.head()
# Out:
#      game_name game_version  player_count room_name           timestamp
# 0  Gorilla Tag         live           548      2QRY 2021-02-26 20:30:49
# 1  Gorilla Tag         live           547      1CNM 2021-02-26 20:18:51
# 2  Gorilla Tag         live           528     2QKYY 2021-02-26 20:06:07
# 3  Gorilla Tag         live           518      3PRX 2021-02-26 19:55:25
# 4  Gorilla Tag         live           490       V9M 2021-02-26 19:44:05

# %%
df.columns = ['game_name', 'game_version',
                'Player Count', 'room_name', 'Time']


params = {"ytick.color": "#000",
            "xtick.color": "#000",
            "axes.labelcolor": "#000",
            "axes.edgecolor": "#000"}
plt.rcParams.update(params)
fig = plt.figure(figsize=(7, 4), dpi=200)
ax = plt.axes()
plt.margins(x=0)
df_filtered.plot(ax=ax, x='Time', y='Player Count', linewidth=2.0, c='#000')
ax.axhline(y=df_filtered['Player Count'].iloc[0], color='#000', linestyle='--')

ax.get_xaxis().set_visible(False)
ax.get_legend().remove()

plt.savefig('graph.png', transparent=True, bbox_inches='tight')
